# %% [markdown]
# # MYNTRA FASHION CLOTHING(DATA SET ANALYSIS)

# %%
import pandas as pd

# %%
df=pd.read_csv('Myntra Fasion Clothing.csv')
df
# Out:
# C:\Users\deepa\AppData\Local\Temp\ipykernel_17280\2715546502.py:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('Myntra Fasion Clothing.csv')
#                                                       URL  Product_id  \
# 0       https://www.myntra.com/jeans/roadster/roadster...     2296012
# 1       https://www.myntra.com/track-pants/locomotive/...    13780156
# 2       https://www.myntra.com/shirts/roadster/roadste...    11895958
# 3       https://www.myntra.com/shapewear/zivame/zivame...     4335679
# 4       https://www.myntra.com/tshirts/roadster/roadst...    11690882
# ...                                                   ...         ...
# 526559  https://www.myntra.com/sweaters/hm/hm-women-be...    16929990
# 526560  https://www.myntra.com/jackets/hm/hm-women-bla...    16026012
# 526561  https://www.myntra.com/dresses/250-designs/250...    17654114
# ...

# %%
df=pd.read_csv('Myntra Fasion Clothing.csv')
df.head(10)
# Out:
# C:\Users\deepa\AppData\Local\Temp\ipykernel_16140\1024293753.py:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('Myntra Fasion Clothing.csv')
#                                                  URL  Product_id  \
# 0  https://www.myntra.com/jeans/roadster/roadster...     2296012
# 1  https://www.myntra.com/track-pants/locomotive/...    13780156
# 2  https://www.myntra.com/shirts/roadster/roadste...    11895958
# 3  https://www.myntra.com/shapewear/zivame/zivame...     4335679
# 4  https://www.myntra.com/tshirts/roadster/roadst...    11690882
# 5  https://www.myntra.com/tops/mast--harbour/mast...     2490950
# 6  https://www.myntra.com/trousers/highlander/hig...     6744434
# 7  https://www.myntra.com/tops/mayra/mayra-pink-e...     8439415
# 8  https://www.myntra.com/tshirts/roadster/roadst...    17381394
# 9  https://www.myntra.com/jeans/herenow/herenow-m...     2359257
#
# ...

# %%
df=pd.read_csv('Myntra Fasion Clothing.csv')
df.tail(5)
# Out:
# C:\Users\deepa\AppData\Local\Temp\ipykernel_16140\2541281361.py:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('Myntra Fasion Clothing.csv')
#                                                       URL  Product_id  \
# 526559  https://www.myntra.com/sweaters/hm/hm-women-be...    16929990
# 526560  https://www.myntra.com/jackets/hm/hm-women-bla...    16026012
# 526561  https://www.myntra.com/dresses/250-designs/250...    17654114
# 526562  https://www.myntra.com/dresses/masaba/masaba-w...    12508700
# 526563  https://www.myntra.com/tshirts/jockey/jockey-w...    17856544
#
#           BrandName Category Individual_category category_by_Gender  \
# 526559          H&M  Western            sweaters              Women
# 526560          H&M  Western             jackets              Women
# 526561  250 DESIGNS  Western             dresses              Women
# ...

# %%
df.describe()
# Out:
#          Product_id  DiscountPrice (in Rs)  OriginalPrice (in Rs)  \
# count  5.265640e+05          333406.000000          526564.000000
# mean   1.506939e+07            1237.444401            2414.068615
# std    3.225710e+06            1052.063517            1916.962914
# min    2.739900e+04             127.000000              99.000000
# 25%    1.388053e+07             659.000000            1299.000000
# 50%    1.597106e+07             952.000000            1999.000000
# 75%    1.734741e+07            1469.000000            2899.000000
# max    1.846435e+07           27996.000000           90000.000000
#
#              Ratings        Reviews
# count  190412.000000  190412.000000
# mean        4.094892      61.990820
# std         0.494158     125.714537
# min         1.000000       0.000000
# 25%         3.900000       8.000000
# 50%         4.200000      18.000000
# 75%         4.400000      52.000000
# max         5.000000     999.000000

# %%
df.dtypes
# Out:
# URL                       object
# Product_id                 int64
# BrandName                 object
# Category                  object
# Individual_category       object
# category_by_Gender        object
# Description               object
# DiscountPrice (in Rs)    float64
# OriginalPrice (in Rs)    float64
# DiscountOffer             object
# SizeOption                object
# Ratings                  float64
# Reviews                  float64
# dtype: object

# %%
##handling missing values
df.isnull().any()
# Out:
# URL                      False
# Product_id               False
# BrandName                False
# Category                 False
# Individual_category      False
# category_by_Gender       False
# Description              False
# DiscountPrice (in Rs)     True
# OriginalPrice (in Rs)    False
# DiscountOffer             True
# SizeOption               False
# Ratings                   True
# Reviews                   True
# dtype: bool

# %%
df

# %%
df_filled=df.fillna(0)
df_filled
# Out:
#                                                       URL  Product_id  \
# 0       https://www.myntra.com/jeans/roadster/roadster...     2296012
# 1       https://www.myntra.com/track-pants/locomotive/...    13780156
# 2       https://www.myntra.com/shirts/roadster/roadste...    11895958
# 3       https://www.myntra.com/shapewear/zivame/zivame...     4335679
# 4       https://www.myntra.com/tshirts/roadster/roadst...    11690882
# ...                                                   ...         ...
# 526559  https://www.myntra.com/sweaters/hm/hm-women-be...    16929990
# 526560  https://www.myntra.com/jackets/hm/hm-women-bla...    16026012
# 526561  https://www.myntra.com/dresses/250-designs/250...    17654114
# 526562  https://www.myntra.com/dresses/masaba/masaba-w...    12508700
# 526563  https://www.myntra.com/tshirts/jockey/jockey-w...    17856544
#
#           BrandName               Category Individual_category  \
# ...

# %%
##filling the missing values with the mean of the column
df['Product_id_fillNA']=df['Product_id'].fillna(df['Product_id'].mean())
df
# Out:
#                                                       URL  Product_id  \
# 0       https://www.myntra.com/jeans/roadster/roadster...     2296012
# 1       https://www.myntra.com/track-pants/locomotive/...    13780156
# 2       https://www.myntra.com/shirts/roadster/roadste...    11895958
# 3       https://www.myntra.com/shapewear/zivame/zivame...     4335679
# 4       https://www.myntra.com/tshirts/roadster/roadst...    11690882
# ...                                                   ...         ...
# 526559  https://www.myntra.com/sweaters/hm/hm-women-be...    16929990
# 526560  https://www.myntra.com/jackets/hm/hm-women-bla...    16026012
# 526561  https://www.myntra.com/dresses/250-designs/250...    17654114
# 526562  https://www.myntra.com/dresses/masaba/masaba-w...    12508700
# 526563  https://www.myntra.com/tshirts/jockey/jockey-w...    17856544
#
#           BrandName               Category Individual_category  \
# ...

# %%
df.dtypes
# Out:
# URL                       object
# Product_id                 int64
# BrandName                 object
# Category                  object
# Individual_category       object
# category_by_Gender        object
# Description               object
# DiscountPrice (in Rs)    float64
# OriginalPrice (in Rs)    float64
# DiscountOffer             object
# SizeOption                object
# Ratings                  float64
# Reviews                  float64
# Product_id_fillNA          int64
# dtype: object

# %%
##renaming columns
df=df.rename(columns={'URL':'LINK'})
df.head()
# Out:
#                                                 LINK  Product_id   BrandName  \
# 0  https://www.myntra.com/jeans/roadster/roadster...     2296012    Roadster
# 1  https://www.myntra.com/track-pants/locomotive/...    13780156  LOCOMOTIVE
# 2  https://www.myntra.com/shirts/roadster/roadste...    11895958    Roadster
# 3  https://www.myntra.com/shapewear/zivame/zivame...     4335679      Zivame
# 4  https://www.myntra.com/tshirts/roadster/roadst...    11690882    Roadster
#
#                 Category Individual_category category_by_Gender  \
# 0            Bottom Wear               jeans                Men
# 1            Bottom Wear         track-pants                Men
# 2                Topwear              shirts                Men
# 3  Lingerie & Sleep Wear           shapewear              Women
# 4                Western             tshirts              Women
#
#                                          Description  DiscountPrice (in Rs)  \
# ...

# %%
# Out:
#                                                  URL  Product_id   BrandName  \
# 0  https://www.myntra.com/jeans/roadster/roadster...     2296012    Roadster
# 1  https://www.myntra.com/track-pants/locomotive/...    13780156  LOCOMOTIVE
# 2  https://www.myntra.com/shirts/roadster/roadste...    11895958    Roadster
# 3  https://www.myntra.com/shapewear/zivame/zivame...     4335679      Zivame
# 4  https://www.myntra.com/tshirts/roadster/roadst...    11690882    Roadster
#
#                 Category Individual_category category_by_Gender  \
# 0            Bottom Wear               jeans                Men
# 1            Bottom Wear         track-pants                Men
# 2                Topwear              shirts                Men
# 3  Lingerie & Sleep Wear           shapewear              Women
# 4                Western             tshirts              Women
#
#                                          Description  DiscountPrice (in Rs)  \
# ...

# %%
df['New DiscountOffer']=df['DiscountOffer'].apply(lambda x:x*2)
df.head()
# Out:
#                                                  URL  Product_id   BrandName  \
# 0  https://www.myntra.com/jeans/roadster/roadster...     2296012    Roadster
# 1  https://www.myntra.com/track-pants/locomotive/...    13780156  LOCOMOTIVE
# 2  https://www.myntra.com/shirts/roadster/roadste...    11895958    Roadster
# 3  https://www.myntra.com/shapewear/zivame/zivame...     4335679      Zivame
# 4  https://www.myntra.com/tshirts/roadster/roadst...    11690882    Roadster
#
#                 Category Individual_category category_by_Gender  \
# 0            Bottom Wear               jeans                Men
# 1            Bottom Wear         track-pants                Men
# 2                Topwear              shirts                Men
# 3  Lingerie & Sleep Wear           shapewear              Women
# 4                Western             tshirts              Women
#
#                                          Description  DiscountPrice (in Rs)  \
# ...

# %%
##data aggression and grouping
df.head()
# Out:
#                                                  URL  Product_id   BrandName  \
# 0  https://www.myntra.com/jeans/roadster/roadster...     2296012    Roadster
# 1  https://www.myntra.com/track-pants/locomotive/...    13780156  LOCOMOTIVE
# 2  https://www.myntra.com/shirts/roadster/roadste...    11895958    Roadster
# 3  https://www.myntra.com/shapewear/zivame/zivame...     4335679      Zivame
# 4  https://www.myntra.com/tshirts/roadster/roadst...    11690882    Roadster
#
#                 Category Individual_category category_by_Gender  \
# 0            Bottom Wear               jeans                Men
# 1            Bottom Wear         track-pants                Men
# 2                Topwear              shirts                Men
# 3  Lingerie & Sleep Wear           shapewear              Women
# 4                Western             tshirts              Women
#
#                                          Description  DiscountPrice (in Rs)  \
# ...

# %%
grouped_mean=df.groupby('DiscountPrice (in Rs)')['Ratings'].mean()
print(grouped_mean)
# Out:
# DiscountPrice (in Rs)
# 127.0      4.4
# 134.0      3.7
# 137.0      4.2
# 139.0      2.4
# 141.0      4.1
#           ...
# 22800.0    NaN
# 23996.0    NaN
# 25515.0    NaN
# 27000.0    NaN
# 27996.0    NaN
# Name: Ratings, Length: 4455, dtype: float64

# %%
grouped_sum=df.groupby(['OriginalPrice (in Rs)','Ratings'])['DiscountPrice (in Rs)'].sum()
print(grouped_sum)
# Out:
# OriginalPrice (in Rs)  Ratings
# 99.00                  4.6            0.0
# 129.00                 4.4          127.0
#                        4.5            0.0
# 139.00                 4.0            0.0
#                        4.4            0.0
#                                    ...
# 28899.00               4.3         7224.0
# 32000.00               4.0        16000.0
# 33762.96               3.7         7089.0
# 36500.00               3.2         7300.0
# 42999.00               1.0            0.0
# Name: DiscountPrice (in Rs), Length: 15194, dtype: float64

# %%
df.groupby(['OriginalPrice (in Rs)','DiscountPrice (in Rs)'])['Ratings'].mean()
# Out:
# OriginalPrice (in Rs)  DiscountPrice (in Rs)
# 129.0                  127.0                    4.400000
# 149.0                  141.0                    4.100000
# 155.0                  147.0                    4.300000
# 179.0                  170.0                    3.966667
# 199.0                  159.0                    4.300000
#                                                   ...
# 39990.0                5998.0                        NaN
# 40400.0                20200.0                       NaN
# 42500.0                8925.0                        NaN
#                        21250.0                       NaN
# 45000.0                8999.0                        NaN
# Name: Ratings, Length: 20228, dtype: float64

# %%
##aggregate multiple functions
grouped_agg=df.groupby('OriginalPrice (in Rs)')['DiscountPrice (in Rs)'].agg(['mean','sum','count'])
grouped_agg
# Out:
#                         mean    sum  count
# OriginalPrice (in Rs)
# 99.0                     NaN    0.0      0
# 129.0                  127.0  127.0      1
# 139.0                    NaN    0.0      0
# 149.0                  141.0  141.0      1
# 150.0                    NaN    0.0      0
# ...                      ...    ...    ...
# 47999.0                  NaN    0.0      0
# 49000.0                  NaN    0.0      0
# 49999.0                  NaN    0.0      0
# 70000.0                  NaN    0.0      0
# 90000.0                  NaN    0.0      0
#
# [4914 rows x 3 columns]

# %%
##merging and joining dataframes
##create sample dataframes
df1=pd.DataFrame({'Key':['A','B','C'],'Value1':[1,2,3]})
df2=pd.DataFrame({'Key':['A','B','F'],'Value2':[4,5,6]})
df
# Out:
#                                                       URL  Product_id  \
# 0       https://www.myntra.com/jeans/roadster/roadster...     2296012
# 1       https://www.myntra.com/track-pants/locomotive/...    13780156
# 2       https://www.myntra.com/shirts/roadster/roadste...    11895958
# 3       https://www.myntra.com/shapewear/zivame/zivame...     4335679
# 4       https://www.myntra.com/tshirts/roadster/roadst...    11690882
# ...                                                   ...         ...
# 526559  https://www.myntra.com/sweaters/hm/hm-women-be...    16929990
# 526560  https://www.myntra.com/jackets/hm/hm-women-bla...    16026012
# 526561  https://www.myntra.com/dresses/250-designs/250...    17654114
# 526562  https://www.myntra.com/dresses/masaba/masaba-w...    12508700
# 526563  https://www.myntra.com/tshirts/jockey/jockey-w...    17856544
#
#           BrandName               Category Individual_category  \
# ...

# %%
df1
# Out:
#   Key  Value1
# 0   A       1
# 1   B       2
# 2   C       3

# %%
df2
# Out:
#   Key  Value2
# 0   A       4
# 1   B       5
# 2   F       6

# %%
##merge dataframe on the key columns
pd.merge(df1,df2,on="Key",how="outer")
# Out:
#   Key  Value1  Value2
# 0   A     1.0     4.0
# 1   B     2.0     5.0
# 2   C     3.0     NaN
# 3   F     NaN     6.0

# %%
##merge dataframe on the key columns
pd.merge(df1,df2,on="Key",how="inner")
# Out:
#   Key  Value1  Value2
# 0   A       1       4
# 1   B       2       5

# %%
##merge dataframe on the key columns
pd.merge(df1,df2,on="Key",how="left")
# Out:
#   Key  Value1  Value2
# 0   A       1     4.0
# 1   B       2     5.0
# 2   C       3     NaN

# %%
##merge dataframe on the key columns
pd.merge(df1,df2,on="Key",how="right")
# Out:
#   Key  Value1  Value2
# 0   A     1.0       4
# 1   B     2.0       5
# 2   F     NaN       6

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Myntra Fasion Clothing.csv')
x=df['Ratings']
y=df['Reviews']

plt.plot(x,y)
plt.xlabel('x axis')
plt.ylabel('y Axis')
plt.title("Basic line plot")
plt.show()
# Out:
# C:\Users\deepa\AppData\Local\Temp\ipykernel_9572\2122863668.py:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('Myntra Fasion Clothing.csv')

# %%
import matplotlib.pyplot as plt

labels=['Product_id','OriginalPrice (in Rs)','Ratings','Reviews']
sizes=['Product_id','OriginalPrice (in Rs)','Ratings','Reviews']
colors=['gold','yellowgreen','lightcoral','lightskyblue']
explode=(0.2,0,0,0)##move out the lst slice

plt.pie(sizes,explode=explode,labels=labels,colors=colors,autopct="%1.1f%%",shadow=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 8
#       5 colors=['gold','yellowgreen','lightcoral','lightskyblue']
#       6 explode=(0.2,0,0,0)##move out the lst slice
# ----> 8 plt.pie(sizes,explode=explode,labels=labels,colors=colors,autopct="%1.1f%%",shadow=True)
#
# File c:\Users\deepa\anaconda3\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# ...
